# %% [markdown]
# # Spectral Diversity
#
# ## Interferometric product is convolution of spectra
#
# ```{figure} figures/wavenumber_shift.png
# ---
# height: 300px
# name: wavenumberoverlap
# ---
#
# ```
#
# ## Wavenumber (spectral) shift
#
#
#
# The main characteristic of the error sources attacked by a priori filtering is the sep- arability of signal and noise in the spectral domain. Consider two image spectra that contain a distinct signal part and noise part. The complex multi- plication of the two images, as applied during interferogram formation, corresponds with a convolution of the two spectra. In the convolution, the noise parts of the two original images will get smeared over all frequencies in the spectrum of the resulting interferogram. Since the noise components cannot be effectively separated at this stage, a posteriori filtering of the interferogram for this type of noise is not very effective.
#
#
# ```{figure} figures/wavenumber_shift.png
# ---
# height: 300px
# name: wavenumberoverlap
# ---
#
# ```
#
# - 2.5.5 (book) A priori filtering

# %% [markdown]
# ## Fringe frequency: reference phase (flat earth phase)
#
# ```{figure} figures/flat_earth_phase.png
# ---
# height: 300px
# name: wavenumberoverlap
# ---
#
# ```
#
# $$
# f_{\phi}= \frac{\partial \phi}{2 \pi \partial R}=- \frac{2B_{\perp}}{\lambda R_1 \tan(\theta_{inc}-\zeta)} \hspace{7mm}\text{[cycles/m]}
# $$

# %% [markdown]
# ## Geometric decorrelation
# :::{card}
# - If incidence angle change, reconstruction phase changes
# - The larger the pixel, the more sensitive it is to a small variation of incidence angle (directivity antenna)
# - Sensitive to slope
# - Senitive to Baseline
# - Sensitive to Doppler
#
# **Leads to Geometric loss of coherence**
#
#
# :::
